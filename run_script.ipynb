# %%
# !git clone https://github.com/motiyaniisha22/rag_automotive.git
# Out:
# Cloning into 'rag_automotive'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 145 (delta 80), reused 12 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (145/145), 14.98 MiB | 23.17 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
# !cd rag_automotive && pip -q install -r requirements.txt

# %%
# !cd rag_automotive && python create_db.py
# Out:
# #### Vector database created successfully !!

# %%
# !cd rag_automotive && python inference.py --json_query "{'make': 'ford', 'model' : 'escape', 'year': '2001', 'issue': 'stuck throttle risk'}"
# Out:
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:00<00:00,  3.19it/s]
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Summary :
# ...
